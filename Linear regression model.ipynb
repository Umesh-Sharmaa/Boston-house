# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C://Users//Umesh sharma//Downloads//HousingData.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df["Price"]=df["MEDV"]

# %%
df=df.drop("MEDV",axis=1)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90    NaN   36.2

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150  0.354342
# ZN      -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800 -0.563801
# INDUS    0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234  0.638431
# CHAS    -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885  0.078831
# NOX      0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188  0.731548
# RM      -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000 -0.247337
# AGE      0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337  1.000000
# DIS     -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246 -0.744844
# RAD      0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847  0.458349
# TAX      0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048  0.509114
# PTRATIO  0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501  0.269226
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# Price       0
# dtype: int64

# %%
df=df.dropna()

# %%
df=df.reset_index()

# %%
df.head(20)
# Out:
#     index     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0       0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296
# 1       1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242
# 2       2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242
# 3       3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222
# 4       5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222
# 5       7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311
# 6       8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311
# 7      10  0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467    5  311
# 8      11  0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267    5  311
# 9      12  0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509    5  311
# 10     13  0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075    4  307
# ...

# %%
df=df.drop("index",axis=1)

# %%
df.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222
# 4   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222
# 5   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311
# 6   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311
# 7   0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467    5  311
# 8   0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267    5  311
# 9   0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509    5  311
# 10  0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075    4  307
# 11  0.62739   0.0   8.14   0.0  0.538  5.834   56.5  4.4986    4  307
# ...

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.188075  0.391552 -0.051970  0.416160 -0.227170  0.341311
# ZN      -0.188075  1.000000 -0.521256 -0.033357 -0.515660  0.343210 -0.568174
# INDUS    0.391552 -0.521256  1.000000  0.049820  0.762737 -0.403068  0.642387
# CHAS    -0.051970 -0.033357  0.049820  1.000000  0.076661  0.095308  0.072644
# NOX      0.416160 -0.515660  0.762737  0.076661  1.000000 -0.316563  0.732540
# RM      -0.227170  0.343210 -0.403068  0.095308 -0.316563  1.000000 -0.248670
# AGE      0.341311 -0.568174  0.642387  0.072644  0.732540 -0.248670  1.000000
# DIS     -0.365052  0.645359 -0.696569 -0.095037 -0.768137  0.218713 -0.753547
# RAD      0.608667 -0.298773  0.591944  0.014102  0.628170 -0.236057  0.443585
# TAX      0.560841 -0.305768  0.734204 -0.026513  0.679824 -0.320561  0.504472
# PTRATIO  0.265428 -0.422164  0.395691 -0.104995  0.210216 -0.390686  0.264968
# ...

# %%
plt.scatter(df["Price"],df["CRIM"])
plt.xlabel("Price")
plt.ylabel("Crime")
# Out:
# Text(0, 0.5, 'Crime')

# %%
plt.scatter(df["Price"],df["RM"])
plt.xlabel("Price")
plt.ylabel("RM")
# Out:
# Text(0, 0.5, 'RM')

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
#Train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=44,test_size=0.3)

# %%
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE      DIS  RAD  TAX  \
# 300  16.81180   0.0  18.10   0.0  0.700  5.277   98.1   1.4261   24  666
# 97    0.22212   0.0  10.01   0.0  0.547  6.092   95.4   2.5480    6  432
# 175   0.62356   0.0   6.20   1.0  0.507  6.879   77.7   3.2721    8  307
# 142   0.07022   0.0   4.05   0.0  0.510  6.020   47.2   3.5549    5  296
# 321  28.65580   0.0  18.10   0.0  0.597  5.155  100.0   1.5894   24  666
# ..        ...   ...    ...   ...    ...    ...    ...      ...  ...  ...
# 387   0.26838   0.0   9.69   0.0  0.585  5.794   70.6   2.8927    6  391
# 59    0.12816  12.5   6.07   0.0  0.409  5.885   33.0   6.4980    4  345
# 173   0.35809   0.0   6.20   1.0  0.507  6.951   88.5   2.8617    8  307
# 241   0.26169   0.0   9.90   0.0  0.544  6.023   90.4   2.8340    4  304
# 276   0.01709  90.0   2.02   0.0  0.410  6.728   36.1  12.1265    5  187
#
#      PTRATIO       B  LSTAT
# 300     20.2  396.90  30.81
# 97      17.8  396.90  17.09
# ...

# %%
#Standard scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
#Model Training
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction 
reg_pred=reg.predict(x_test)

# %%
#Evaluation metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
# Out:
# 3.4187649765196397
# 21.375429802514056

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,reg_pred))
# Out:
# 0.7358853426745824

# %%
#New prediction
x.iloc[0].values.reshape(1,-1).shape
# Out:
# (1, 13)

# %%
scaler.transform(x.iloc[0].values.reshape(1,-1))
# Out:
# C:\Users\Umesh sharma\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.39343161,  0.30372672, -1.27946053, -0.28005602, -0.13133024,
#          0.42317799, -0.15237342,  0.12656895, -0.98054442, -0.66478944,
#         -1.64822356,  0.4305515 , -1.07072499]])

# %%
reg.predict(scaler.transform(x.iloc[0].values.reshape(1,-1)))
# Out:
# C:\Users\Umesh sharma\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([29.58327703])

# %%
#Pickling
import pickle

# %%
pickle.dump(scaler,open("scaler.pkl","wb"))

# %%
pickle.dump(reg,open("house.pkl","wb"))

# %%
pickled=pickle.load(open("house.pkl","rb"))
